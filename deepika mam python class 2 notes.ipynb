# %% [markdown]
# # python class -2

# %%
type("city")
# Out:
# str

# %%
type('19')
# Out:
# str

# %%
int('10')
# Out:
# 10

# %%
d = '355'
type(d)
# Out:
# str

# %%
e = '5'
type(e)
# Out:
# str

# %%
d +e
# Out:
# '3555'

# %%
int(e) + int(d) #we can chnage an int into string and also change string into integer(but only with numerical value)
# Out:
# 360

# %%
type(d)
# Out:
# str

# %%
x = int(d)
type(x)
# Out:
# int

# %%
y = int(e)
type(y)
# Out:
# int

# %%
x + y
# Out:
# 360

# %%
k = 'mobile'
m = 100

# %%
int(k) # we can not change string with text value to integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13612\3681117209.py in <module>
# ----> 1 int(k)
#
# ValueError: invalid literal for int() with base 10: 'mobile'

# %%
j = '46.66'   # can not change  string with float data into int 
int(j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13612\3999485964.py in <module>
#       1 j = '46.66'
# ----> 2 int(j)
#
# ValueError: invalid literal for int() with base 10: '46.66'

# %%
l = '56' # only the string with int data will change into the the integer 
int(l)
# Out:
# 56

# %%
j
# Out:
# '46.66'

# %%
float(j) #it will work , this float string data can be converted to float data.
# Out:
# 46.66

# %%
a = input("enter the value of a " )
a
# Out:
# enter the value of a 12
# '12'

# %%
b = input("enter the value of b")
b
# Out:
# enter the value of b65
# '65'

# %%
print(a + b) 
type(a+ b) # both the values are in string form
# Out:
# 1265
# str

# %%
c = int(input("enter your number :"))
c
type(c)
# Out:
# enter your number56
# int

# %%
d = int(input("enter your 2nd number")) #this is also typecasting.
d
# Out:
# enter your 2nd number78
# 78

# %%
c + d # now both the variables holds  integer data and their addition be in int form
# Out:
# 134

# %%
int(a) + int(b)
# Out:
# 77

# %%
o = float(input("enter a  decimal number here"))
# Out:
# enter a  decimal number here67.6

# %%
o
type(o)
# Out:
# float

# %%
length = int(input("enter  the length "))
breadth= int(input("enter the  breadth "))
area = length * breadth
print( "the area of rectangle is ",area)
print("the area of rectangle with " , length , "and breadth" , breadth , "is " , area)
# Out:
# enter  the length 23
# enter the  breadth 45
# the area of rectangle is  1035
# the area of rectangle with  23 and breadth 45 is  1035

# %%
length = float(input("enter  the length "))
breadth= float(input("enter the  breadth "))
area = length * breadth
print( "the area of rectangle is ",area)
print("the area of rectangle with " , length , "and breadth" , breadth , "is " , area)
# Out:
# enter  the length 34.98
# enter the  breadth 89.90
# the area of rectangle is  3144.7019999999998
# the area of rectangle with  34.98 and breadth 89.9 is  3144.7019999999998

# %%
R = int(input("enter the radius"))
pie = 3.14
area_circle = pie * R **2
print(area_circle)
print("area of circle with Radius" , R , "is" , area_circle)
# Out:
# enter the radius34
# 3629.84
# area of circle with Radius 34 is 3629.84

# %%
R = int(input("enter the radius"))
pie = 3.14
circumference = 2*pie*R
print("circumference of circle with radius" , R , "is" , circumference)
# Out:
# enter the radius56
# circumference of circle with radius 56 is 351.68

# %% [markdown]
# # Data structures :
# basically Data structures are collection of Data

# %% [markdown]
# inside the data structures we can collect different different item in different ways.

# %% [markdown]
# # Four types of data structures are here :
# 1.list   2.tuple   3.dictionary   4.sets

# %% [markdown]
# #  1. list

# %% [markdown]
# list are ordered collection of python.

# %% [markdown]
# list are indexed

# %% [markdown]
# list are mutable(editable)

# %% [markdown]
# # 2.Tuples

# %% [markdown]
# tuples also are ordered collection

# %% [markdown]
# tuples are indexed also

# %% [markdown]
# tuples are non mutable

# %% [markdown]
# # 3.Dictionary

# %% [markdown]
# Dictionary are key value pair.

# %% [markdown]
# they are  also mutable . they allow duplicate value.

# %% [markdown]
# # 4.Sets

# %% [markdown]
# Sets are unordered collection of item.

# %% [markdown]
# they are non index

# %% [markdown]
# they are immutable and they  do not allow duplicate value

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# homogeneous = same data type

# %% [markdown]
# hetrogeneous = different data type

# %%
list1 = [1,22,3,4,5,67,7,8,8,9,7,6]

# %%
list2 = ['apple ' , 'mango' , 'banana']

# %%
list3 = [23.3 , 56.6 , 45.5 , 98.99]  #this list holds  homogeneous data

# %%
list4 = [12,'hello' , 657.5 ] #this list holds hetrogeneous data

# %%
list1
# Out:
# [1, 22, 3, 4, 5, 67, 7, 8, 8, 9, 7, 6]

# %%
list3 = [23,33,44,54,16,76,34,98]
list3
# Out:
# [23, 33, 44, 54, 16, 76, 34, 98]

# %%
 list = [99.9 , 90.67 , 'a' , 'list' , 12 , 45]

# %%
list
# Out:
# [99.9, 90.67, 'a', 'list', 12, 45]

# %%
list = ['mango' , 'banana' , 'kela' , 'pomegranate' , 'orange' , 'kiwi' , 'dragon fruit' ]
list
# Out:
# ['mango', 'banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']

# %%
list5 = ['A' , 'B' , 'C' , 'D']
list5
# Out:
# ['A', 'B', 'C', 'D']

# %%
list6 = list

# %%
list
# Out:
# ['mango', 'banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']

# %% [markdown]
# # Index

# %% [markdown]
# index will start from 0 and from the back side it start from -1 , for example in above list at 0 index there is mango

# %% [markdown]
# and in -1 index there is 'dragon fruit'

# %% [markdown]
#  How to find data at different index

# %%
list[0] #at 0th index there is mango
# Out:
# 'mango'

# %%
list[-1] # at -1 index there is dragon fruit
# Out:
# 'dragon fruit'

# %%
list[5]
# Out:
# 'kiwi'

# %%
list[-5]
# Out:
# 'kela'

# %%
list3 = [1,2,33,66,867,56,99,68,56,49,3,65,66,89]

# %%
len(list3)
# Out:
# 14

# %%
list3[7]
# Out:
# 68

# %% [markdown]
# # Slicing :

# %% [markdown]
# slicing means to cut a piece  [:]

# %%
list3[:] # colon is basially range
# Out:
# [1, 2, 33, 66, 867, 56, 99, 68, 56, 49, 3, 65, 66, 89]

# %%
list3[1:15] # at the end index(15-1) value will be shown
# Out:
# [2, 33, 66, 867, 56, 99, 68, 56, 49, 3, 65, 66, 89]

# %%
list6[0:2]
# Out:
# ['mango', 'banana']

# %%
list6[0:8]
# Out:
# ['mango', 'banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']

# %%
list[3:6]
# Out:
# ['pomegranate', 'orange', 'kiwi']

# %%
list[1:] # it will automatically pick last index
# Out:
# ['banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']

# %%
list[:] # it will automatically take all the data
# Out:
# ['mango', 'banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']

# %%
list[:7] #it will automatically pick from 0th index element
# Out:
# ['mango', 'banana', 'kela', 'pomegranate', 'orange', 'kiwi', 'dragon fruit']
